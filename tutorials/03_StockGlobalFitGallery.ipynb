# %% [markdown]
# # 03: A deep demo of every stock global fit

# %% [markdown]
# **This notebook targets the development stack (LATW `dev` branch).** It
# builds and runs the *installed* stock global fits from the development
# LISA Analysis Tools packages (`LISAanalysistools/install.sh`), not the pip
# releases. No Colab:
#
# ```bash
# git clone https://github.com/lisa-analysis-tools/lisa-analysis-tools.git LISAanalysistools
# bash LISAanalysistools/install.sh
# ```

# %%
import os
for _v in ("OMP_NUM_THREADS", "OPENBLAS_NUM_THREADS", "MKL_NUM_THREADS",
           "VECLIB_MAXIMUM_THREADS", "NUMEXPR_NUM_THREADS"):
    os.environ.setdefault(_v, "1")
os.environ.setdefault("MAKE_DIAGNOSTIC_PLOTS", "0")

import gc
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from copy import deepcopy
from lisatools.utils.constants import *

from lisatools.globalfit.stock import erebor

# The two readouts this gallery leans on are methods on the installed classes,
# not helpers defined here:
#   fit.describe()          -- the configuration; once built, each branch also
#                              reports the *Setup it resolved into (+ sub-bands).
#                              describe(full=True) dumps EVERY field.
#   curr.summarize_run(...) -- what the sampler produced: log-like + per-branch
#                              chain shapes and alive-leaf counts, read off the
#                              fit's own HDF backend.

# Each variant writes to its own file under a fresh gallery dir, so the
# several stock fits in this single notebook never collide on one HDF5
# backend (eryn rejects reusing a backend whose branch set differs).
import shutil
GALLERY_DIR = "./gf_output_gallery/"
shutil.rmtree(GALLERY_DIR, ignore_errors=True)

# Slightly larger default text so labels/ticks/titles read clearly in the
# rendered figures.
plt.rcParams.update({"font.size": 12, "axes.titlesize": 13, "axes.labelsize": 12,
                     "xtick.labelsize": 11, "ytick.labelsize": 11, "legend.fontsize": 11})
# Out:
# cupy not found, using numpy instead. This will be very slow for large runs. Please install cupy and a compatible CUDA version for GPU acceleration.

# %% [markdown]
# Right after the quickstart, this notebook is the **gallery**: an early,
# catalogue-style overview that builds every registered stock variant through
# its `*_lite` twin, reads its structure, and points out how each one differs
# from the six-branch `all_sources` flagship. The shared machinery underneath
# these variants — the data layer, the settings pyramid, and the recipe of
# moves — is unpacked later in [`02`](02_StockGlobalFitsInDepth.ipynb).
#
# Every run here is deliberately tiny -- **synthetic in-process data, two
# sampler iterations, laptop grids** -- so the whole notebook fits its time
# budget and needs no external data files. None of these short chains is
# converged; they exercise the pipeline and show the shape of each fit's
# output. The one-line **production** launch for each variant is given in
# its section.
#
# ### How to read this notebook
#
# One `##` section per variant. Each builds the lite twin and prints how it
# is composed (`describe()` / `list_moves()` / branch list). The three light
# variants (`gb_no_fg`, `noise_only`, `noise_sgwb`) also **run** a couple of
# iterations and read the branches back with the `summarize` helper. The two
# heaviest -- `full_year_combined` and the six-branch `all_sources` -- we
# **build and inspect** rather than sample (the full `all_sources` build +
# run + structured-output read is notebook 01's job; re-running it here would
# duplicate it and strain a laptop).

# %% [markdown]
# ## `gb_no_fg` — galactic binaries only
#
# **TL;DR.** A GB-only reversible-jump fit with a **fixed PSD** and **no
# foreground branch**, restricted to f > 6 mHz so unresolved confusion is
# out of band. The single `gb` branch uses the WDM chunked-heterodyne
# likelihood. Supported data: `mojito` (default) / `synthetic`.

# %% [markdown]
# **The injected data, straight after `build()`.** `build()` is what turns the
# config into data: it loads or synthesises every branch's stream, pours it onto
# the analysis domain, and hands it back on `curr.general_info`. So the first
# thing worth looking at — before any sampling — is what the fit is actually
# going to see.

# %%
fit = erebor.gb_no_fg_lite(file_store_dir=GALLERY_DIR, base_file_name="gallery_gb_no_fg_lite")
fit.general.data_mode = "synthetic"    # 2-source in-process GB stream
fit.general.synthetic_injections = "prior"   # prior draws; zero mojito needed
fit.general.num_iterations = 2          # explicit (the lite preset pins 10)
fit.gb.nleaves_max = 4                   # cap the RJ leaf budget for speed
fit.gb.num_repeat_proposals = 1
print(fit.describe())
# Out:
# GBNoForegroundLiteGlobalFit (gb_no_fg_lite) — Laptop-smoke twin of gb_no_fg: two-week span, 10 iterations, 4 walkers x 2 temps, 2 GB repeat proposals, CPU.
#   built: False
#   headline:
#     nwalkers = 4
#     ntemps = 2
#     dt = 2.5
#     num_iterations = 2
#     file_store_dir = './gf_output_gallery/'
#     base_file_name = 'gallery_gb_no_fg_lite'
#     gpus = None
#     gpu_backend = 'auto'
#     tobs_target = 1209600.0
#     min_freq = 0.006
#     max_freq = 0.025
#     tdi_chan = 'XYZ'
#     window_tukey_alpha = 0.05
#     mojito_data_path = '/Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/'
#     use_gpu = False
#   branches: ['gb']
#     gb: GBNoFgGBSettings
#   recipe:
#     [pe] gb_pe:
#         rj_prior  <- stock branch=gb
#   setup_function: setup_recipe

# %%
curr = fit.build()
fit.run()
curr.summarize_run("gb_no_fg_lite");

# The injected data this variant will fit. heatmap() is a method on the WDM
# class, so the axes come out in physical units (seconds, Hz) and the colormap
# is the WDM default for free. mag/log plot log10|coefficients|: without them
# the plot reads blank, since the injected sources occupy a few of ~137
# frequency layers -- a couple of pixels on an empty plane. heatmap() spends
# the y-label on the channel name (X/Y/Z), so we label the frequency axis here.
data = curr.general_info.input_data_residual_array
fig, axes = data.heatmap(mag=True, log=True)
fig.set_size_inches(8, 4.5)
axes[-1].set_xlabel("time [s]")
fig.supylabel("frequency [Hz]")
fig.suptitle("gb_no_fg_lite — injected data, log10 |WDM coefficients|")
plt.show()

# Free this variant before the next build. Five stock fits run in ONE kernel
# here, and a built fit holds its whole data array -- plus heatmap(log=True)
# makes a dense log10|.| copy, which for the year-long variants is the
# difference between finishing and an OOM-killed kernel on an 8 GB laptop.
plt.close("all")
data = fit = curr = None
gc.collect()
# Out:
# 2026-07-15 20:53:59,903 - GeneralSetup - DEBUG - Saving h5 backend to ./gf_output_gallery/gallery_gb_no_fg_lite_testing.h5
# 2026-07-15 20:53:59,904 - GeneralSetup - DEBUG - Saving artifacts to ./gf_output_gallery/gallery_gb_no_fg_lite_artifacts/
# 2026-07-15 20:54:03,686 - GeneralSetup - INFO - Using fixed PSD kwargs: {'psd_params': [1.5e-11, 3e-15], 'galfor_params': None}
# 2026-07-15 20:54:03,687 - GeneralSetup - DEBUG - Preprocess setting: plot_folder = ./gf_output_gallery/gallery_gb_no_fg_lite_artifacts/
# 2026-07-15 20:54:03,687 - GeneralSetup - DEBUG - Preprocess setting: highpass_kwargs = None
# 2026-07-15 20:54:03,688 - GeneralSetup - DEBUG - Preprocess setting: trim_kwargs = None
# 2026-07-15 20:54:03,689 - GeneralSetup - DEBUG - Preprocess setting: Tobs = None
# 2026-07-15 20:54:03,689 - GeneralSetup - DEBUG - Preprocess setting: normalize = False
# 2026-07-15 20:54:04,007 - GeneralSetup - INFO - Domain setting: force_backend = cpu
# 2026-07-15 20:54:04,007 - GeneralSetup - INFO - Domain setting: _backend_name = lisatools_cpu
# 2026-07-15 20:54:04,008 - GeneralSetup - INFO - Domain setting: Nt = 336
# 2026-07-15 20:54:04,009 - GeneralSetup - INFO - Domain setting: Nf = 1440
# 2026-07-15 20:54:04,010 - GeneralSetup - INFO - Domain setting: data_dt = 2.5
# 2026-07-15 20:54:04,010 - GeneralSetup - INFO - Domain setting: N = 483840
# 2026-07-15 20:54:04,011 - GeneralSetup - INFO - Domain setting: Tobs = 1209600.0
# 2026-07-15 20:54:04,012 - GeneralSetup - INFO - Domain setting: layer_dt = 3600.0
# 2026-07-15 20:54:04,012 - GeneralSetup - INFO - Domain setting: layer_df = 0.0001388888888888889
# 2026-07-15 20:54:04,013 - GeneralSetup - INFO - Domain setting: t0 = 0.0
# 2026-07-15 20:54:04,013 - GeneralSetup - INFO - Domain setting: is_complex = False
# 2026-07-15 20:54:04,014 - GeneralSetup - INFO - Domain setting: min_freq_input = 0.006
# 2026-07-15 20:54:04,015 - GeneralSetup - INFO - Domain setting: _ind_min_f = 44
# 2026-07-15 20:54:04,015 - GeneralSetup - INFO - Domain setting: _min_freq = 0.006
# 2026-07-15 20:54:04,016 - GeneralSetup - INFO - Domain setting: max_freq_input = 0.025
# 2026-07-15 20:54:04,016 - GeneralSetup - INFO - Domain setting: _ind_max_f = 180
# 2026-07-15 20:54:04,017 - GeneralSetup - INFO - Domain setting: _max_freq = 0.025
# 2026-07-15 20:54:04,017 - GeneralSetup - INFO - Domain setting: min_time_input = 72000.0
# 2026-07-15 20:54:04,018 - GeneralSetup - INFO - Domain setting: _ind_min_t = 20
# 2026-07-15 20:54:04,018 - GeneralSetup - INFO - Domain setting: _min_time = 72000.0
# 2026-07-15 20:54:04,019 - GeneralSetup - INFO - Domain setting: max_time_input = 1137600.0
# 2026-07-15 20:54:04,019 - GeneralSetup - INFO - Domain setting: _ind_max_t = 316
# 2026-07-15 20:54:04,020 - GeneralSetup - INFO - Domain setting: _max_time = 1137600.0
# 2026-07-15 20:54:04,020 - GeneralSetup - INFO - Domain setting: Nthalf = 168
# 2026-07-15 20:54:04,021 - GeneralSetup - INFO - Domain setting: oversample = 16
# 2026-07-15 20:54:04,021 - GeneralSetup - INFO - Domain setting: dOmega = 0.0008726646259971648
# 2026-07-15 20:54:04,022 - GeneralSetup - INFO - Domain setting: A = 0.000545415391248228
# 2026-07-15 20:54:04,023 - GeneralSetup - INFO - Domain setting: WAVELET_FILTER_CONSTANT = 4
# 2026-07-15 20:54:04,025 - GeneralSetup - INFO - Domain setting: omega = [-2.18166156e-03 -2.16867548e-03 -2.15568940e-03 -2.14270332e-03
#  6.99167250e+00 6.36177052e+00 5.75625118e+00 5.17768679e+00
#  4.62827052e+00 4.10980667e+00 3.62370797e+00 3.17099890e+00
#  2.75232415e+00 2.36796141e+00 2.01783746e+00 1.70154696e+00
#  1.41837328e+00 1.16731089e+00 9.47089018e-01 7.56196490e-01
#  5.92907654e-01 4.55309636e-01 3.41331078e-01 2.48772682e-01
#  1.75339905e-01 1.18678148e-01 7.64107907e-02 4.61803837e-02
#  2.56933000e-02 1.27680731e-02 5.38764103e-03 1.75566552e-03
#  3.57076560e-04 2.29728158e-05 1.31095313e-15 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# 2026-07-15 20:54:04,040 - lisatools.globalfit.stock.erebor.variants.gb_no_fg - INFO - GB band: [7.361111e-03, 7.777778e-03] Hz (3 WDM layers, layer_df=1.3889e-04 Hz)
# 2026-07-15 20:54:04,042 - GBSetup - INFO - GB f0 prior range is set from 0.0075 to 0.0076389
# 2026-07-15 20:54:04,043 - GBSetup - INFO - The number of subbands is 3
# 2026-07-15 20:54:04,043 - GBSetup - INFO - Min freq of subbands is 0.007361111111111111
# 2026-07-15 20:54:04,044 - GBSetup - INFO - Max freq of subbands is 0.0077777777777777776
# 2026-07-15 20:54:04,445 - GlobalFit - DEBUG - need to adjust file path
# 2026-07-15 20:54:04,446 - GlobalFit - DEBUG - update this somehow
# 2026-07-15 20:54:04,459 - GlobalFit - DEBUG - state loaded
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/detector.py:1621: RuntimeWarning: divide by zero encountered in divide
#   Sa_a = Sa_a_in * (1.0 + (0.4e-3 / frq) ** 2) * (1.0 + (frq / 8e-3) ** 4)
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/detector.py:1623: RuntimeWarning: divide by zero encountered in power
#   Sa_d = Sa_a * (2.0 * np.pi * frq) ** (-4.0)
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/detector.py:1625: RuntimeWarning: invalid value encountered in multiply
#   Sa_nu = Sa_d * (2.0 * np.pi * frq / C_SI) ** 2
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/detector.py:1630: RuntimeWarning: divide by zero encountered in divide
#   Soms_d = Soms_d_in * (1.0 + (2.0e-3 / f) ** 4)
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/detector.py:1632: RuntimeWarning: invalid value encountered in multiply
#   Soms_nu = Soms_d * (2.0 * np.pi * frq / C_SI) ** 2
# 2026-07-15 20:54:05,600 - lisatools.globalfit.run - WARNING - rebuild_residuals: branch 'gb' has neither a signal_gen entry nor a get_templates hook; skipped.
# 2026-07-15 20:54:05,601 - lisatools.globalfit.run - INFO - rebuilt residuals from state coords/inds.
# 2026-07-15 20:54:05,602 - GlobalFit - DEBUG - acs setup done
# 2026-07-15 20:54:05,610 - lisatools.globalfit.run - INFO - initial log likelihood: [-652.77467493 -652.77467493 -652.77467493 -652.77467493]
# 2026-07-15 20:54:09,417 - lisatools.globalfit.stock.erebor.variants.gb_no_fg - INFO - Chunked-het GB likelihood: Nf=1440 Nt=336 Nt_sub=256 N_sparse=256 N_cp_sig=48 N_cp_orbit=32 (domain t0 0.000000e+00 -> het t_obs_start=1.000000e+04, t_ref=1.000000e+04, chunk_t_starts=[1.000000e+04, 2.980000e+05])
# 2026-07-15 20:54:09,418 - lisatools.globalfit.recipe - WARNING - No 'GB' catalogue found; GB SNR-cut injection skipped.
# 2026-07-15 20:54:18,062 - lisatools.globalfit.recipe - DEBUG - GBGPU initialized with gpus: None and backend: <gbgpu.cutils.GBGPUCpuBackend object at 0x13b4bfb00>
# need to setup moves that use parallel resources
# 2026-07-15 20:54:18,084 - lisatools.globalfit.recipe - DEBUG - Setting periodicity of move <lisatools.globalfit.moves.globalfitmove.GFCombineMove object at 0x13b538800> to <eryn.utils.periodic.PeriodicContainer object at 0x141c75f10>
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2026-07-15 20:54:18,141 - lisatools.globalfit.moves.gbspecialstretch - DEBUG - Start check: start_diffs=array([0., 0., 0., 0.]), check=array([0., 0., 0., 0.])
# 2026-07-15 20:54:18,142 - lisatools.globalfit.moves.gbspecialstretch - INFO - Number of active leaves before proposal: [0 0 0 0]
# 2026-07-15 20:54:27,821 - lisatools.globalfit.moves.gbspecialstretch - INFO - rj_prior: band unit complete after 4 pick rounds (8 cells).
# 2026-07-15 20:54:27,830 - lisatools.globalfit.moves.gbspecialstretch - INFO - Alive sources per temp after run_proposal: [0, 4]
# 2026-07-15 20:54:27,832 - lisatools.globalfit.moves.gbspecialstretch - INFO - Runtime of rj_prior proposal is 9.634 seconds.
# 2026-07-15 20:54:27,843 - lisatools.globalfit.moves.gbspecialstretch - DEBUG - After proposal check: start_diffs=array([0., 0., 0., 0.]), check=array([0., 0., 0., 0.])
# 2026-07-15 20:54:28,451 - lisatools.globalfit.moves.gbspecialstretch - DEBUG - After tempering check: start_diffs=array([0., 0., 0., 0.]), check=array([0., 0., 0., 0.])
# 2026-07-15 20:54:28,454 - lisatools.globalfit.moves.gbspecialstretch - INFO - Runtime of rj_prior tempering is 0.61 seconds.
# 2026-07-15 20:54:28,455 - lisatools.globalfit.moves.gbspecialstretch - INFO - Full runtime of rj_prior is 10.281 seconds.
# 2026-07-15 20:54:28,456 - lisatools.globalfit.moves.gbspecialstretch - INFO - Number of active leaves in cold chain after proposal: [0 0 0 0]
# 2026-07-15 20:54:28,475 - lisatools.globalfit.moves.gbspecialstretch - INFO - Current number of active sources in cold chain is [0 0 0 0]
# 2026-07-15 20:54:28,475 - lisatools.globalfit.moves.gbspecialstretch - INFO - [GB_TIMING rj_prior] total=10.302s tracked=10.289s untracked=0.013s | run_proposal=9.634s inmodel_repeats=8.297s buffer_build=1.027s run_tempering=0.593s temper_buffer=0.545s rj_step=0.296s ll_checks=0.030s temper_swap_score=0.023s ll_inject_final=0.017s sorter_build=0.012s pick=0.002s resid_open_close=0.002s write_back=0.000s sorter_rebuild=0.000s unit_open_close=0.000s band_info=0.000s temper_open_close=0.000s mempool_free=0.000s friend_index=0.000s | cells=8 pick_rounds=4 picked_sources=32
# 1it [00:10, 10.36s/it]
# 1it [00:10, 10.36s/it]
#  50%|█████     | 1/2 [00:10<00:10, 10.40s/it]
# 0it [00:00, ?it/s]
# 2026-07-15 20:54:28,539 - lisatools.globalfit.moves.gbspecialstretch - DEBUG - Start check: start_diffs=array([0., 0., 0., 0.]), check=array([0., 0., 0., 0.])
# 2026-07-15 20:54:28,540 - lisatools.globalfit.moves.gbspecialstretch - INFO - Number of active leaves before proposal: [0 0 0 0]
# 2026-07-15 20:54:33,422 - lisatools.globalfit.moves.gbspecialstretch - INFO - rj_prior: band unit complete after 4 pick rounds (8 cells).
# 2026-07-15 20:54:33,428 - lisatools.globalfit.moves.gbspecialstretch - INFO - Alive sources per temp after run_proposal: [0, 2]
# 2026-07-15 20:54:33,429 - lisatools.globalfit.moves.gbspecialstretch - INFO - Runtime of rj_prior proposal is 4.887 seconds.
# 2026-07-15 20:54:33,441 - lisatools.globalfit.moves.gbspecialstretch - DEBUG - After proposal check: start_diffs=array([0., 0., 0., 0.]), check=array([0., 0., 0., 0.])
# 2026-07-15 20:54:34,021 - lisatools.globalfit.moves.gbspecialstretch - DEBUG - After tempering check: start_diffs=array([0., 0., 0., 0.]), check=array([0., 0., 0., 0.])
# 2026-07-15 20:54:34,023 - lisatools.globalfit.moves.gbspecialstretch - INFO - Runtime of rj_prior tempering is 0.581 seconds.
# 2026-07-15 20:54:34,024 - lisatools.globalfit.moves.gbspecialstretch - INFO - Full runtime of rj_prior is 5.503 seconds.
# 2026-07-15 20:54:34,025 - lisatools.globalfit.moves.gbspecialstretch - INFO - Number of active leaves in cold chain after proposal: [0 0 0 0]
# 2026-07-15 20:54:34,042 - lisatools.globalfit.moves.gbspecialstretch - INFO - Current number of active sources in cold chain is [0 0 0 0]
# 2026-07-15 20:54:34,043 - lisatools.globalfit.moves.gbspecialstretch - INFO - [GB_TIMING rj_prior] total=5.522s tracked=5.511s untracked=0.011s | run_proposal=4.887s inmodel_repeats=4.109s run_tempering=0.564s temper_buffer=0.512s buffer_build=0.479s rj_step=0.292s ll_checks=0.030s temper_swap_score=0.026s ll_inject_final=0.016s sorter_build=0.010s resid_open_close=0.002s pick=0.001s sorter_rebuild=0.000s unit_open_close=0.000s write_back=0.000s temper_open_close=0.000s band_info=0.000s mempool_free=0.000s friend_index=0.000s | cells=8 pick_rounds=4 picked_sources=32
# 1it [00:05,  5.52s/it]
# 1it [00:05,  5.52s/it]
# 100%|██████████| 2/2 [00:15<00:00,  7.55s/it]
# 100%|██████████| 2/2 [00:15<00:00,  7.98s/it]
# 2026-07-15 20:54:34,082 - lisatools.globalfit.run - INFO - Residuals saved.
# === gb_no_fg_lite (sampled) ===
# branches   : ['gb']
# log_like   : (2, 2, 4)  final chain (temp 0): [-652.77 -652.77 -652.77 -652.77]
#   gb      chain (2, 2, 4, 4, 8)            alive-leaves(temp 0,last)=0
# 20304

# %% [markdown]
# **How it differs from `all_sources`:** just the one `gb` branch (vs.
# six), a *fixed* instrument PSD instead of a fitted `psd`/`galfor`, and a
# narrow high-frequency band. The `gb` chain is `(nsteps, ntemps, nwalkers,
# nleaves_max, ndim=8)` — a reversible-jump *forest*, so the alive-leaf
# count is itself sampled.
#
# **Production launch:** `erebor.gb_no_fg()` (mojito L1 GB galaxy, full band,
# `num_iterations` from `NUM_ITERATIONS`); scale with `NWALKERS`,
# `TOBS_TARGET`, `GB_MODE=search`.

# %% [markdown]
# ## `noise_only` — instrument PSD + galactic foreground
#
# **TL;DR.** No GW *source* branches at all: it jointly fits the instrument
# **`psd`** (2 params) and the hyperbolic-tangent galactic-confusion
# **`galfor`** foreground on a self-consistent synthetic WDM noise
# realization, both sampled by the single `PSDMove`. Data: `synthetic` only
# (swap `data_processor_class` for real data).

# %%
fit = erebor.noise_only_lite(file_store_dir=GALLERY_DIR, base_file_name="gallery_noise_only_lite")
fit.general.num_iterations = 2
print(fit.describe())
print("\nmoves:\n" + fit.list_moves())
# Out:
# NoiseOnlyLiteGlobalFit (noise_only_lite) — Laptop-smoke twin of noise_only: quarter-length time grid, 10 iterations, 4 walkers x 2 temps, CPU.
#   built: False
#   headline:
#     nwalkers = 4
#     ntemps = 2
#     dt = 5.0
#     num_iterations = 2
#     file_store_dir = './gf_output_gallery/'
#     base_file_name = 'gallery_noise_only_lite'
#     gpus = None
#     gpu_backend = 'auto'
#     tobs_target = 7776000.0
#     min_freq = 0.0003
#     max_freq = 0.008
#     tdi_chan = 'XYZ'
#     window_tukey_alpha = 0.0
#     mojito_data_path = '/Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/'
#     use_gpu = False
#   branches: ['psd', 'galfor']
#     psd: NoisePSDSettings
#     galfor: GalForSettings
#   recipe:
#     [pe] noise_pe:
#         psd_pe  <- stock branch=psd
#   setup_function: setup_recipe
#
# moves:
# [pe] noise_pe:
#     psd_pe  <- stock branch=psd

# %%
curr = fit.build()
fit.run()
curr.summarize_run("noise_only_lite");

# the injected data this variant will fit
data = curr.general_info.input_data_residual_array
fig, axes = data.heatmap(mag=True, log=True)
fig.set_size_inches(8, 4.5)
axes[-1].set_xlabel("time [s]")
fig.supylabel("frequency [Hz]")
fig.suptitle("noise_only_lite — injected data, log10 |WDM coefficients|")
plt.show()

# Free this variant before the next build. Five stock fits run in ONE kernel
# here, and a built fit holds its whole data array -- plus heatmap(log=True)
# makes a dense log10|.| copy, which for the year-long variants is the
# difference between finishing and an OOM-killed kernel on an 8 GB laptop.
plt.close("all")
data = fit = curr = None
gc.collect()
# Out:
# 2026-07-15 20:54:35,598 - lisatools.globalfit.stock.erebor.noise - INFO - noise parameters read from /Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/data/INSTRUMENT/L1/NOISE_731d_2.5s_L1_source0_0_20251206T220508924302Z.h5: Soms_d=1.496182e-11, Sa_a=2.982412e-15
# 2026-07-15 20:54:35,601 - GeneralSetup - DEBUG - Saving h5 backend to ./gf_output_gallery/gallery_noise_only_lite_testing.h5
# 2026-07-15 20:54:35,602 - GeneralSetup - DEBUG - Saving artifacts to ./gf_output_gallery/gallery_noise_only_lite_artifacts/
# 2026-07-15 20:54:35,603 - lisatools.globalfit.preprocessing - INFO - L1DataLoader initialized with data folder: /Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/data
# 2026-07-15 20:54:35,604 - lisatools.globalfit.preprocessing - INFO - Source types to load: ['NOISE']
# 2026-07-15 20:54:35,605 - lisatools.globalfit.preprocessing - INFO - Source IDs: None
# 2026-07-15 20:54:35,606 - lisatools.globalfit.preprocessing - INFO - Orbits class: L1Orbits
# 2026-07-15 20:54:35,607 - lisatools.globalfit.preprocessing - INFO - Orbits kwargs: {'force_backend': 'cpu', 'frame': 'icrs'}
# [load_data] L1Orbits(...) (incl. _setup) took 5.40s
# [load_data] orbits._ensure_configured() took 6.44s
# 2026-07-15 20:54:47,452 - lisatools.globalfit.preprocessing - INFO - Initialized orbits from NOISE file.
# [load_data] NOISE f.tdis.xyz_doppler[:] took 2.97s shape=(25246480, 3)
# 2026-07-15 20:54:50,670 - lisatools.globalfit.preprocessing - INFO - Loaded NOISE data from /Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/data/INSTRUMENT/L1/NOISE_731d_2.5s_L1_source0_0_20251206T220508924302Z.h5
# 2026-07-15 20:54:50,671 - lisatools.globalfit.preprocessing - INFO - data, times and orbits initialized from NOISE file.
# 2026-07-15 20:54:50,671 - lisatools.globalfit.preprocessing - INFO - TDI time step: 2.5 seconds
# 2026-07-15 20:54:50,672 - lisatools.globalfit.preprocessing - INFO - TDI sampling frequency: 0.4 Hz
# 2026-07-15 20:54:50,674 - GeneralSetup - INFO - Using fixed PSD kwargs: {'psd_params': [1.5e-11, 3e-15], 'galfor_params': None}
# 2026-07-15 20:54:50,674 - GeneralSetup - DEBUG - Preprocess setting: plot_folder = ./gf_output_gallery/gallery_noise_only_lite_artifacts/
# 2026-07-15 20:54:50,675 - GeneralSetup - DEBUG - Preprocess setting: highpass_kwargs = {'cutoff': 2e-05, 'order': 2, 'zero_phase': True}
# 2026-07-15 20:54:50,677 - GeneralSetup - DEBUG - Preprocess setting: trim_kwargs = {'duration': 720000, 'is_percent': False, 'trimming_type': 'from_each_end'}
# 2026-07-15 20:54:50,677 - GeneralSetup - DEBUG - Preprocess setting: Tobs = 983040.0
# 2026-07-15 20:54:50,678 - GeneralSetup - DEBUG - Preprocess setting: downsample_kwargs = {'target_fs': 0.2}
# 2026-07-15 20:54:50,678 - GeneralSetup - DEBUG - Preprocess setting: normalize = False
# 2026-07-15 20:54:50,679 - lisatools.globalfit.preprocessing - INFO - Applying highpass filter...
# 2026-07-15 20:54:55,099 - lisatools.globalfit.preprocessing - INFO - Downsampling data...
# 2026-07-15 20:54:57,515 - lisatools.globalfit.preprocessing - INFO - Updated parameters: N=12623240, T=63116195.000000015
# 2026-07-15 20:54:57,535 - lisatools.globalfit.preprocessing - INFO - Trimming data...
# 2026-07-15 20:54:57,536 - lisatools.globalfit.preprocessing - INFO - Trimming 720000s (144000 samples) from each end of the data.
# 2026-07-15 20:54:57,536 - lisatools.globalfit.preprocessing - INFO - Updated parameters: N=12335240, T=61676195.000000015
# 2026-07-15 20:54:57,537 - lisatools.globalfit.preprocessing - INFO - Keeping first 983040.0s (196608 samples) of the data.
# 2026-07-15 20:54:57,537 - lisatools.globalfit.preprocessing - INFO - Updated parameters: N=196608, T=983035.0
# 2026-07-15 20:54:57,831 - GeneralSetup - INFO - Domain setting: force_backend = cpu
# 2026-07-15 20:54:57,832 - GeneralSetup - INFO - Domain setting: _backend_name = lisatools_cpu
# 2026-07-15 20:54:57,833 - GeneralSetup - INFO - Domain setting: Nt = 256
# 2026-07-15 20:54:57,834 - GeneralSetup - INFO - Domain setting: Nf = 768
# 2026-07-15 20:54:57,834 - GeneralSetup - INFO - Domain setting: data_dt = 5.0
# 2026-07-15 20:54:57,835 - GeneralSetup - INFO - Domain setting: N = 196608
# 2026-07-15 20:54:57,836 - GeneralSetup - INFO - Domain setting: Tobs = 983040.0
# 2026-07-15 20:54:57,837 - GeneralSetup - INFO - Domain setting: layer_dt = 3840.0
# 2026-07-15 20:54:57,838 - GeneralSetup - INFO - Domain setting: layer_df = 0.00013020833333333333
# 2026-07-15 20:54:57,839 - GeneralSetup - INFO - Domain setting: t0 = 0.0
# 2026-07-15 20:54:57,839 - GeneralSetup - INFO - Domain setting: is_complex = False
# 2026-07-15 20:54:57,840 - GeneralSetup - INFO - Domain setting: min_freq_input = 0.0003
# 2026-07-15 20:54:57,840 - GeneralSetup - INFO - Domain setting: _ind_min_f = 3
# 2026-07-15 20:54:57,841 - GeneralSetup - INFO - Domain setting: _min_freq = 0.0003
# 2026-07-15 20:54:57,841 - GeneralSetup - INFO - Domain setting: max_freq_input = 0.008
# 2026-07-15 20:54:57,842 - GeneralSetup - INFO - Domain setting: _ind_max_f = 61
# 2026-07-15 20:54:57,843 - GeneralSetup - INFO - Domain setting: _max_freq = 0.008
# 2026-07-15 20:54:57,843 - GeneralSetup - INFO - Domain setting: min_time_input = None
# 2026-07-15 20:54:57,844 - GeneralSetup - INFO - Domain setting: _ind_min_t = 0
# 2026-07-15 20:54:57,844 - GeneralSetup - INFO - Domain setting: _min_time = None
# 2026-07-15 20:54:57,845 - GeneralSetup - INFO - Domain setting: max_time_input = None
# 2026-07-15 20:54:57,846 - GeneralSetup - INFO - Domain setting: _ind_max_t = 255
# 2026-07-15 20:54:57,846 - GeneralSetup - INFO - Domain setting: _max_time = None
# 2026-07-15 20:54:57,847 - GeneralSetup - INFO - Domain setting: Nthalf = 128
# 2026-07-15 20:54:57,847 - GeneralSetup - INFO - Domain setting: oversample = 16
# 2026-07-15 20:54:57,848 - GeneralSetup - INFO - Domain setting: dOmega = 0.0008181230868723419
# 2026-07-15 20:54:57,848 - GeneralSetup - INFO - Domain setting: A = 0.0010226538585904274
# 2026-07-15 20:54:57,849 - GeneralSetup - INFO - Domain setting: WAVELET_FILTER_CONSTANT = 4
# 2026-07-15 20:54:57,852 - GeneralSetup - INFO - Domain setting: omega = [-4.09061543e-03 -4.05865750e-03 -4.02669957e-03 -3.99474164e-03
#  -3.96278370e-03 -3.93082577e-03 -3.89886784e-03 -3.86690990e-03
#  -3.83495197e-03 -3.80299404e-03 -3.77103610e-03 -3.73907817e-03
#  -3.70712024e-03 -3.67516230e-03 -3.64320437e-03 -3.61124644e-03
+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352799e+01
#  1.56352763e+01 1.56352581e+01 1.56351919e+01 1.56350004e+01
#  1.56345296e+01 1.56335074e+01 1.56314935e+01 1.56278252e+01
#  1.56215612e+01 1.56114302e+01 1.55957872e+01 1.55725830e+01
#  1.55393521e+01 1.54932214e+01 1.54309443e+01 1.53489606e+01
#  1.52434834e+01 1.51106112e+01 1.49464626e+01 1.47473293e+01
#  1.45098393e+01 1.42311246e+01 1.39089831e+01 1.35420259e+01
#  1.31297997e+01 1.26728776e+01 1.21729095e+01 1.16326288e+01
#  1.10558128e+01 1.04471977e+01 9.81235281e+00 9.15751965e+00
#  8.48942588e+00 7.81508328e+00 7.14158110e+00 6.47588498e+00
#  5.82465082e+00 5.19406115e+00 4.58968927e+00 4.01639427e+00
#  3.47824753e+00 2.97848951e+00 2.51951385e+00 2.10287493e+00
#  1.72931451e+00 1.39880303e+00 1.11059170e+00 8.63272321e-01
#  6.54842636e-01 4.82776232e-01 3.44096737e-01 2.35457054e-01
#  1.53224857e-01 9.35759360e-02 5.25971107e-02 2.64003507e-02
#  1.12495555e-02 3.70120854e-03 7.59876973e-04 4.93393834e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# 2026-07-15 20:54:57,855 - GeneralSetup - DEBUG - Initializing GPU orbits with kwargs: {'armlength': 2500000000.0, 'force_backend': 'cpu', 'frame': 'icrs', 'linear_interp_dt': 500.0}
# 2026-07-15 20:55:01,943 - PSDSetup - INFO - Using custom priors for PSD branch
# 2026-07-15 20:55:28,046 - GlobalFit - DEBUG - need to adjust file path
# 2026-07-15 20:55:28,072 - GlobalFit - DEBUG - update this somehow
# 2026-07-15 20:55:28,098 - GlobalFit - DEBUG - state loaded
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/stochastic.py:178: RuntimeWarning: divide by zero encountered in power
#   * (f ** (-7.0 / 3.0))
# /Users/mkatz/Research/lisa_sprint_2026/LISAanalysistools/src/lisatools/sensitivity.py:491: RuntimeWarning: invalid value encountered in multiply
#   return Sh * t
# 2026-07-15 20:55:28,835 - lisatools.globalfit.run - INFO - rebuilt residuals from state coords/inds.
# 2026-07-15 20:55:28,856 - GlobalFit - DEBUG - acs setup done
# 2026-07-15 20:55:28,887 - lisatools.globalfit.run - INFO - initial log likelihood: [ 1584648.92831967  1847900.64923769 -1807161.24969207  1897747.14111058]
# need to setup moves that use parallel resources
# 2026-07-15 20:55:29,015 - lisatools.globalfit.recipe - DEBUG - Setting periodicity of move <lisatools.globalfit.moves.globalfitmove.GFCombineMove object at 0x13b4d64e0> to <eryn.utils.periodic.PeriodicContainer object at 0x13b4ef7a0>
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# psd update:   0%|          | 0/5 [00:00<?, ?it/s]
# psd update:  20%|██        | 1/5 [00:02<00:09,  2.29s/it]
# psd update:  40%|████      | 2/5 [00:02<00:04,  1.34s/it]
# psd update:  60%|██████    | 3/5 [00:03<00:02,  1.05s/it]
# psd update:  80%|████████  | 4/5 [00:04<00:00,  1.11it/s]
# psd update: 100%|██████████| 5/5 [00:05<00:00,  1.15it/s]
# psd update: 100%|██████████| 5/5 [00:05<00:00,  1.03s/it]
# 1it [00:06,  6.52s/it]
# 1it [00:06,  6.52s/it]
#  50%|█████     | 1/2 [00:06<00:06,  6.56s/it]
# 0it [00:00, ?it/s]
# psd update:   0%|          | 0/5 [00:00<?, ?it/s]
# psd update:  20%|██        | 1/5 [00:02<00:09,  2.44s/it]
# psd update:  40%|████      | 2/5 [00:03<00:04,  1.40s/it]
# psd update:  60%|██████    | 3/5 [00:03<00:02,  1.08s/it]
# psd update:  80%|████████  | 4/5 [00:04<00:00,  1.13it/s]
# psd update: 100%|██████████| 5/5 [00:04<00:00,  1.31it/s]
# psd update: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# 1it [00:06,  6.28s/it]
# 1it [00:06,  6.28s/it]
# 100%|██████████| 2/2 [00:12<00:00,  6.41s/it]
# 100%|██████████| 2/2 [00:12<00:00,  6.44s/it]
# 2026-07-15 20:55:41,906 - lisatools.globalfit.run - INFO - Residuals saved.
# === noise_only_lite (sampled) ===
# branches   : ['psd', 'galfor']
# log_like   : (2, 2, 4)  final chain (temp 0): [1928420.45 1928122.84 1867460.3  1342267.76]
#   psd     chain (2, 2, 4, 1, 2)            alive-leaves(temp 0,last)=4
#   galfor  chain (2, 2, 4, 1, 5)            alive-leaves(temp 0,last)=4
# 14465

# %% [markdown]
# **How it differs from `all_sources`:** the `psd` + `galfor` branches
# here are *exactly* the noise branches `all_sources` also carries — but
# with no source branches to subtract, so the residual **is** the noise. The
# injected truths (`PSD_INJECTION`, `GALFOR_INJECTION`) parameterize the
# covariance the data are drawn from and sit inside the sampled priors, so a
# converged run recovers them. Both branches are fixed-count (`nleaves_max =
# 1`), unlike the RJ source forests.
#
# **Production launch:** `erebor.noise_only()` (longer grid, more
# iterations).

# %% [markdown]
# ## `noise_sgwb` — PSD + foreground + a stochastic background
#
# **TL;DR.** `noise_only` plus a third branch: a power-law **`sgwb`**
# stochastic gravitational-wave background, fit jointly through the same
# `PSDMove`. Data: `synthetic` only.

# %%
fit = erebor.noise_sgwb_lite(file_store_dir=GALLERY_DIR, base_file_name="gallery_noise_sgwb_lite")
fit.general.num_iterations = 2
print("branches:", list(fit.branches))
print(fit.list_moves())
# Out:
# branches: ['psd', 'galfor', 'sgwb']
# [pe] noise_pe:
#     psd_pe  <- stock branch=psd

# %%
curr = fit.build()
fit.run()
curr.summarize_run("noise_sgwb_lite");

# the injected data this variant will fit
data = curr.general_info.input_data_residual_array
fig, axes = data.heatmap(mag=True, log=True)
fig.set_size_inches(8, 4.5)
axes[-1].set_xlabel("time [s]")
fig.supylabel("frequency [Hz]")
fig.suptitle("noise_sgwb_lite — injected data, log10 |WDM coefficients|")
plt.show()

# Free this variant before the next build. Five stock fits run in ONE kernel
# here, and a built fit holds its whole data array -- plus heatmap(log=True)
# makes a dense log10|.| copy, which for the year-long variants is the
# difference between finishing and an OOM-killed kernel on an 8 GB laptop.
plt.close("all")
data = fit = curr = None
gc.collect()
# Out:
# 2026-07-15 20:55:44,259 - lisatools.globalfit.stock.erebor.noise - INFO - noise parameters read from /Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/data/INSTRUMENT/L1/NOISE_731d_2.5s_L1_source0_0_20251206T220508924302Z.h5: Soms_d=1.496182e-11, Sa_a=2.982412e-15
# 2026-07-15 20:55:44,261 - GeneralSetup - DEBUG - Saving h5 backend to ./gf_output_gallery/gallery_noise_sgwb_lite_testing.h5
# 2026-07-15 20:55:44,263 - GeneralSetup - DEBUG - Saving artifacts to ./gf_output_gallery/gallery_noise_sgwb_lite_artifacts/
# 2026-07-15 20:55:44,264 - lisatools.globalfit.preprocessing - INFO - L1DataLoader initialized with data folder: /Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/data
# 2026-07-15 20:55:44,266 - lisatools.globalfit.preprocessing - INFO - Source types to load: ['NOISE']
# 2026-07-15 20:55:44,266 - lisatools.globalfit.preprocessing - INFO - Source IDs: None
# 2026-07-15 20:55:44,267 - lisatools.globalfit.preprocessing - INFO - Orbits class: L1Orbits
# 2026-07-15 20:55:44,268 - lisatools.globalfit.preprocessing - INFO - Orbits kwargs: {'force_backend': 'cpu', 'frame': 'icrs'}
# [load_data] L1Orbits(...) (incl. _setup) took 2.01s
# [load_data] orbits._ensure_configured() took 4.75s
# 2026-07-15 20:55:51,034 - lisatools.globalfit.preprocessing - INFO - Initialized orbits from NOISE file.
# [load_data] NOISE f.tdis.xyz_doppler[:] took 1.88s shape=(25246480, 3)
# 2026-07-15 20:55:53,142 - lisatools.globalfit.preprocessing - INFO - Loaded NOISE data from /Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/data/INSTRUMENT/L1/NOISE_731d_2.5s_L1_source0_0_20251206T220508924302Z.h5
# 2026-07-15 20:55:53,143 - lisatools.globalfit.preprocessing - INFO - data, times and orbits initialized from NOISE file.
# 2026-07-15 20:55:53,144 - lisatools.globalfit.preprocessing - INFO - TDI time step: 2.5 seconds
# 2026-07-15 20:55:53,144 - lisatools.globalfit.preprocessing - INFO - TDI sampling frequency: 0.4 Hz
# 2026-07-15 20:55:53,145 - GeneralSetup - INFO - Using fixed PSD kwargs: {'psd_params': [1.5e-11, 3e-15], 'galfor_params': None}
# 2026-07-15 20:55:53,146 - GeneralSetup - DEBUG - Preprocess setting: plot_folder = ./gf_output_gallery/gallery_noise_sgwb_lite_artifacts/
# 2026-07-15 20:55:53,146 - GeneralSetup - DEBUG - Preprocess setting: highpass_kwargs = {'cutoff': 2e-05, 'order': 2, 'zero_phase': True}
# 2026-07-15 20:55:53,146 - GeneralSetup - DEBUG - Preprocess setting: trim_kwargs = {'duration': 720000, 'is_percent': False, 'trimming_type': 'from_each_end'}
# 2026-07-15 20:55:53,147 - GeneralSetup - DEBUG - Preprocess setting: Tobs = 983040.0
# 2026-07-15 20:55:53,148 - GeneralSetup - DEBUG - Preprocess setting: downsample_kwargs = {'target_fs': 0.2}
# 2026-07-15 20:55:53,148 - GeneralSetup - DEBUG - Preprocess setting: normalize = False
# 2026-07-15 20:55:53,149 - lisatools.globalfit.preprocessing - INFO - Applying highpass filter...
# 2026-07-15 20:55:56,875 - lisatools.globalfit.preprocessing - INFO - Downsampling data...
# 2026-07-15 20:55:59,242 - lisatools.globalfit.preprocessing - INFO - Updated parameters: N=12623240, T=63116195.000000015
# 2026-07-15 20:55:59,262 - lisatools.globalfit.preprocessing - INFO - Trimming data...
# 2026-07-15 20:55:59,262 - lisatools.globalfit.preprocessing - INFO - Trimming 720000s (144000 samples) from each end of the data.
# 2026-07-15 20:55:59,263 - lisatools.globalfit.preprocessing - INFO - Updated parameters: N=12335240, T=61676195.000000015
# 2026-07-15 20:55:59,263 - lisatools.globalfit.preprocessing - INFO - Keeping first 983040.0s (196608 samples) of the data.
# 2026-07-15 20:55:59,264 - lisatools.globalfit.preprocessing - INFO - Updated parameters: N=196608, T=983035.0
# 2026-07-15 20:55:59,540 - GeneralSetup - INFO - Domain setting: force_backend = cpu
# 2026-07-15 20:55:59,541 - GeneralSetup - INFO - Domain setting: _backend_name = lisatools_cpu
# 2026-07-15 20:55:59,541 - GeneralSetup - INFO - Domain setting: Nt = 256
# 2026-07-15 20:55:59,542 - GeneralSetup - INFO - Domain setting: Nf = 768
# 2026-07-15 20:55:59,542 - GeneralSetup - INFO - Domain setting: data_dt = 5.0
# 2026-07-15 20:55:59,543 - GeneralSetup - INFO - Domain setting: N = 196608
# 2026-07-15 20:55:59,544 - GeneralSetup - INFO - Domain setting: Tobs = 983040.0
# 2026-07-15 20:55:59,544 - GeneralSetup - INFO - Domain setting: layer_dt = 3840.0
# 2026-07-15 20:55:59,545 - GeneralSetup - INFO - Domain setting: layer_df = 0.00013020833333333333
# 2026-07-15 20:55:59,546 - GeneralSetup - INFO - Domain setting: t0 = 0.0
# 2026-07-15 20:55:59,546 - GeneralSetup - INFO - Domain setting: is_complex = False
# 2026-07-15 20:55:59,547 - GeneralSetup - INFO - Domain setting: min_freq_input = 0.0003
# 2026-07-15 20:55:59,547 - GeneralSetup - INFO - Domain setting: _ind_min_f = 3
# 2026-07-15 20:55:59,548 - GeneralSetup - INFO - Domain setting: _min_freq = 0.0003
# 2026-07-15 20:55:59,549 - GeneralSetup - INFO - Domain setting: max_freq_input = 0.008
# 2026-07-15 20:55:59,549 - GeneralSetup - INFO - Domain setting: _ind_max_f = 61
# 2026-07-15 20:55:59,550 - GeneralSetup - INFO - Domain setting: _max_freq = 0.008
# 2026-07-15 20:55:59,551 - GeneralSetup - INFO - Domain setting: min_time_input = None
# 2026-07-15 20:55:59,551 - GeneralSetup - INFO - Domain setting: _ind_min_t = 0
# 2026-07-15 20:55:59,552 - GeneralSetup - INFO - Domain setting: _min_time = None
# 2026-07-15 20:55:59,552 - GeneralSetup - INFO - Domain setting: max_time_input = None
# 2026-07-15 20:55:59,553 - GeneralSetup - INFO - Domain setting: _ind_max_t = 255
# 2026-07-15 20:55:59,553 - GeneralSetup - INFO - Domain setting: _max_time = None
# 2026-07-15 20:55:59,554 - GeneralSetup - INFO - Domain setting: Nthalf = 128
# 2026-07-15 20:55:59,554 - GeneralSetup - INFO - Domain setting: oversample = 16
# 2026-07-15 20:55:59,555 - GeneralSetup - INFO - Domain setting: dOmega = 0.0008181230868723419
# 2026-07-15 20:55:59,556 - GeneralSetup - INFO - Domain setting: A = 0.0010226538585904274
# 2026-07-15 20:55:59,556 - GeneralSetup - INFO - Domain setting: WAVELET_FILTER_CONSTANT = 4
+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352804e+01
#  1.56352804e+01 1.56352804e+01 1.56352804e+01 1.56352799e+01
#  1.56352763e+01 1.56352581e+01 1.56351919e+01 1.56350004e+01
#  1.56345296e+01 1.56335074e+01 1.56314935e+01 1.56278252e+01
#  1.56215612e+01 1.56114302e+01 1.55957872e+01 1.55725830e+01
#  1.55393521e+01 1.54932214e+01 1.54309443e+01 1.53489606e+01
#  1.52434834e+01 1.51106112e+01 1.49464626e+01 1.47473293e+01
#  1.45098393e+01 1.42311246e+01 1.39089831e+01 1.35420259e+01
#  1.31297997e+01 1.26728776e+01 1.21729095e+01 1.16326288e+01
#  1.10558128e+01 1.04471977e+01 9.81235281e+00 9.15751965e+00
#  8.48942588e+00 7.81508328e+00 7.14158110e+00 6.47588498e+00
#  5.82465082e+00 5.19406115e+00 4.58968927e+00 4.01639427e+00
#  3.47824753e+00 2.97848951e+00 2.51951385e+00 2.10287493e+00
#  1.72931451e+00 1.39880303e+00 1.11059170e+00 8.63272321e-01
#  6.54842636e-01 4.82776232e-01 3.44096737e-01 2.35457054e-01
#  1.53224857e-01 9.35759360e-02 5.25971107e-02 2.64003507e-02
#  1.12495555e-02 3.70120854e-03 7.59876973e-04 4.93393834e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# 2026-07-15 20:55:59,561 - GeneralSetup - DEBUG - Initializing GPU orbits with kwargs: {'armlength': 2500000000.0, 'force_backend': 'cpu', 'frame': 'icrs', 'linear_interp_dt': 500.0}
# 2026-07-15 20:56:02,909 - PSDSetup - INFO - Using custom priors for PSD branch
# 2026-07-15 20:56:02,914 - SGWBSetup - INFO - Using custom priors for SGWB branch
# 2026-07-15 20:56:29,320 - GlobalFit - DEBUG - need to adjust file path
# 2026-07-15 20:56:29,349 - GlobalFit - DEBUG - update this somehow
# 2026-07-15 20:56:29,441 - GlobalFit - DEBUG - state loaded
# 2026-07-15 20:56:30,386 - lisatools.globalfit.run - WARNING - rebuild_residuals: branch 'sgwb' has neither a signal_gen entry nor a get_templates hook; skipped.
# 2026-07-15 20:56:30,389 - lisatools.globalfit.run - INFO - rebuilt residuals from state coords/inds.
# 2026-07-15 20:56:30,391 - GlobalFit - DEBUG - acs setup done
# 2026-07-15 20:56:30,422 - lisatools.globalfit.run - INFO - initial log likelihood: [1945666.87964294 1912455.02664084 1886599.58905256 1919248.57492385]
# need to setup moves that use parallel resources
# 2026-07-15 20:56:30,852 - lisatools.globalfit.recipe - DEBUG - Setting periodicity of move <lisatools.globalfit.moves.globalfitmove.GFCombineMove object at 0x13b4bc7a0> to <eryn.utils.periodic.PeriodicContainer object at 0x13b4c1610>
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# psd update:   0%|          | 0/5 [00:00<?, ?it/s]
# psd update:  20%|██        | 1/5 [00:03<00:15,  3.93s/it]
# psd update:  40%|████      | 2/5 [00:04<00:06,  2.19s/it]
# psd update:  60%|██████    | 3/5 [00:05<00:03,  1.57s/it]
# psd update:  80%|████████  | 4/5 [00:06<00:01,  1.29s/it]
# psd update: 100%|██████████| 5/5 [00:07<00:00,  1.01s/it]
# psd update: 100%|██████████| 5/5 [00:07<00:00,  1.42s/it]
# 1it [00:09,  9.42s/it]
# 1it [00:09,  9.42s/it]
#  50%|█████     | 1/2 [00:09<00:09,  9.47s/it]
# 0it [00:00, ?it/s]
# psd update:   0%|          | 0/5 [00:00<?, ?it/s]
# psd update:  20%|██        | 1/5 [00:02<00:09,  2.35s/it]
# psd update:  40%|████      | 2/5 [00:02<00:03,  1.22s/it]
# psd update:  60%|██████    | 3/5 [00:03<00:01,  1.04it/s]
# psd update:  80%|████████  | 4/5 [00:04<00:00,  1.11it/s]
# psd update: 100%|██████████| 5/5 [00:04<00:00,  1.48it/s]
# psd update: 100%|██████████| 5/5 [00:04<00:00,  1.11it/s]
# 1it [00:06,  6.16s/it]
# 1it [00:06,  6.16s/it]
# 100%|██████████| 2/2 [00:15<00:00,  7.54s/it]
# 100%|██████████| 2/2 [00:15<00:00,  7.83s/it]
# 2026-07-15 20:56:46,531 - lisatools.globalfit.run - INFO - Residuals saved.
# === noise_sgwb_lite (sampled) ===
# branches   : ['psd', 'galfor', 'sgwb']
# log_like   : (2, 2, 4)  final chain (temp 0): [1895524.96 1936756.75 1939507.48 1798244.85]
#   psd     chain (2, 2, 4, 1, 2)            alive-leaves(temp 0,last)=4
#   galfor  chain (2, 2, 4, 1, 5)            alive-leaves(temp 0,last)=4
#   sgwb    chain (2, 2, 4, 1, 2)            alive-leaves(temp 0,last)=4
# 14495

# %% [markdown]
# **How it differs from `noise_only`:** one extra `sgwb` branch (a
# 2-param power law, `log10_A @ 25 Hz` + slope). All three noise branches —
# `psd`, `galfor`, `sgwb` — ride the *single* `PSDMove`; there is still no
# source branch. The SGWB prior is widened from the GLASS default so it
# contains the injected amplitude.
#
# **Production launch:** `erebor.noise_sgwb()`. (The SGWB posterior is not
# validated at this smoke size — it is built end-to-end for the machinery.)

# %% [markdown]
# ## `full_year_combined` — the heavy multi-leaf source branches
#
# **TL;DR.** The MBH + EMRI + SOBBH source branches (no GB, no noise
# branches) over a long window, each a **multi-leaf** catalogue-driven
# forest. Fixed instrument noise + an annually-modulated galactic foreground
# are baked into the sensitivity. Waveform paths: **SOBBH TDI-on-the-fly**,
# **MBH + EMRI legacy**. Data: `mojito` (default) / `synthetic`.

# %%
fit = erebor.full_year_combined_lite(file_store_dir=GALLERY_DIR, base_file_name="gallery_full_year_combined_lite")
fit.general.data_mode = "synthetic"     # build MBH/EMRI/SOBBH streams in-process
fit.general.synthetic_injections = "prior"   # prior draws; zero mojito needed
fit.general.num_iterations = 2
print(fit.describe())
# Out:
# FullYearCombinedLiteGlobalFit (full_year_combined_lite) — Laptop-smoke twin of full_year_combined: one month instead of a year, 10 iterations, 4 walkers x 2 temps, CPU.
#   built: False
#   headline:
#     nwalkers = 4
#     ntemps = 2
#     dt = 2.5
#     num_iterations = 2
#     file_store_dir = './gf_output_gallery/'
#     base_file_name = 'gallery_full_year_combined_lite'
#     gpus = None
#     gpu_backend = 'auto'
#     tobs_target = 2592000.0
#     min_freq = 0.0001
#     max_freq = 0.025
#     tdi_chan = 'XYZ'
#     window_tukey_alpha = 0.0
#     mojito_data_path = '/Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/'
#     use_gpu = False
#   branches: ['emri']
#     emri: SourceEMRISettings
#   recipe:
#     [pe] full_pe:
#         emri_pe  <- stock branch=emri
#   setup_function: setup_recipe

# %%
# Built, not sampled here: build() already resolves every branch, loads/builds
# the data, and materializes the recipe -- which is what this gallery is about.
# The two heaviest fits are only inspected; the full build+run+read cycle is in
# notebook 01. Once built, describe() reports each branch's resolved *Setup.
curr = fit.build()          # full_year_combined_lite
print(curr.describe())

# the injected data this variant will fit
data = curr.general_info.input_data_residual_array
fig, axes = data.heatmap(mag=True, log=True)
fig.set_size_inches(8, 4.5)
axes[-1].set_xlabel("time [s]")
fig.supylabel("frequency [Hz]")
fig.suptitle("full_year_combined_lite — injected data, log10 |WDM coefficients|")
plt.show()

# Free this variant before the next build. Five stock fits run in ONE kernel
# here, and a built fit holds its whole data array -- plus heatmap(log=True)
# makes a dense log10|.| copy, which for the year-long variants is the
# difference between finishing and an OOM-killed kernel on an 8 GB laptop.
plt.close("all")
data = fit = curr = None
gc.collect()
# Out:
# 2026-07-15 20:56:48,300 - GeneralSetup - DEBUG - Saving h5 backend to ./gf_output_gallery/gallery_full_year_combined_lite_testing.h5
# 2026-07-15 20:56:48,301 - GeneralSetup - DEBUG - Saving artifacts to ./gf_output_gallery/gallery_full_year_combined_lite_artifacts/
# 2026-07-15 20:56:48,650 - few - DEBUG - Initializing integrator with func=<class 'few.trajectory.ode.flux.KerrEccEqFlux'>, downsample=None, buffer_length=10000
# 2026-07-15 20:56:48,652 - few - DEBUG - Configuration file not found in '/Users/mkatz/Research/lisa_sprint_2026/LATW/tutorials/few.ini'
# 2026-07-15 20:56:48,653 - few - DEBUG - Configuration file not found in '/Users/mkatz/Library/Application Support/few.ini'
# 2026-07-15 20:56:48,654 - few - DEBUG - Configuration file not found in '/Library/Application Support/few/v2.0/few.ini'
# 2026-07-15 20:56:48,655 - few - DEBUG - ConfigInitialization: final configuration entries are
# 2026-07-15 20:56:48,656 - few - DEBUG -  ignore_cfg=False (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,656 - few - DEBUG -  ignore_env=False (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,657 - few - DEBUG -  config_file=None (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,657 - few - DEBUG -  log_level=30 (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,657 - few - DEBUG -  log_format=None (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,658 - few - DEBUG -  file_registry_path=None (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,658 - few - DEBUG -  file_storage_path=/Users/mkatz/Research/lisa_sprint_2026/FastEMRIWaveforms/src/few/data (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,659 - few - DEBUG -  file_download_path=/Users/mkatz/Research/lisa_sprint_2026/FastEMRIWaveforms/src/few/data (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,659 - few - DEBUG -  file_allow_download=True (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,660 - few - DEBUG -  file_integrity_check=once (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,660 - few - DEBUG -  file_extra_paths=[PosixPath('/Users/mkatz/Research/lisa_sprint_2026/FastEMRIWaveforms/src/few/data')] (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,660 - few - DEBUG -  file_disabled_tags=None (from: ConfigSource.DEFAULT)
# 2026-07-15 20:56:48,661 - few - DEBUG -  enabled_backends=None (from: ConfigSource.DEFAULT)
# EMRI inject signal 1 of 1 [start]
# EMRI inject signal 1 of 1 [end]
# 2026-07-15 20:58:05,212 - GeneralSetup - INFO - Using fixed PSD kwargs: {'psd_params': None, 'galfor_params': None}
# 2026-07-15 20:58:05,224 - GeneralSetup - DEBUG - Preprocess setting: plot_folder = ./gf_output_gallery/gallery_full_year_combined_lite_artifacts/
# 2026-07-15 20:58:05,226 - GeneralSetup - DEBUG - Preprocess setting: highpass_kwargs = None
# 2026-07-15 20:58:05,228 - GeneralSetup - DEBUG - Preprocess setting: trim_kwargs = None
# 2026-07-15 20:58:05,229 - GeneralSetup - DEBUG - Preprocess setting: Tobs = None
# 2026-07-15 20:58:05,231 - GeneralSetup - DEBUG - Preprocess setting: normalize = False
# 2026-07-15 20:58:05,784 - GeneralSetup - INFO - Domain setting: force_backend = cpu
# 2026-07-15 20:58:05,786 - GeneralSetup - INFO - Domain setting: _backend_name = lisatools_cpu
# 2026-07-15 20:58:05,786 - GeneralSetup - INFO - Domain setting: Nt = 64
# 2026-07-15 20:58:05,787 - GeneralSetup - INFO - Domain setting: Nf = 16000
# 2026-07-15 20:58:05,788 - GeneralSetup - INFO - Domain setting: data_dt = 2.5
# 2026-07-15 20:58:05,789 - GeneralSetup - INFO - Domain setting: N = 1024000
# 2026-07-15 20:58:05,790 - GeneralSetup - INFO - Domain setting: Tobs = 2560000.0
# 2026-07-15 20:58:05,790 - GeneralSetup - INFO - Domain setting: layer_dt = 40000.0
# 2026-07-15 20:58:05,791 - GeneralSetup - INFO - Domain setting: layer_df = 1.25e-05
# 2026-07-15 20:58:05,792 - GeneralSetup - INFO - Domain setting: t0 = 0.0
# 2026-07-15 20:58:05,793 - GeneralSetup - INFO - Domain setting: is_complex = False
# 2026-07-15 20:58:05,793 - GeneralSetup - INFO - Domain setting: min_freq_input = 0.0001
# 2026-07-15 20:58:05,794 - GeneralSetup - INFO - Domain setting: _ind_min_f = 8
# 2026-07-15 20:58:05,794 - GeneralSetup - INFO - Domain setting: _min_freq = 0.0001
# 2026-07-15 20:58:05,795 - GeneralSetup - INFO - Domain setting: max_freq_input = 0.025
# 2026-07-15 20:58:05,796 - GeneralSetup - INFO - Domain setting: _ind_max_f = 2000
# 2026-07-15 20:58:05,796 - GeneralSetup - INFO - Domain setting: _max_freq = 0.025
# 2026-07-15 20:58:05,797 - GeneralSetup - INFO - Domain setting: min_time_input = 800000.0
-02
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# 2026-07-15 20:58:05,834 - EMRISetup - INFO - Using betas: [1.         0.83333333 0.69444444 0.5787037  0.48225309 0.40187757
#  0.33489798 0.27908165 0.23256804 0.1938067  0.16150558 0.13458799
#  0.11215665 0.09346388 0.07788657 0.06490547 0.05408789 0.04507324
#  0.03756104 0.03130086 0.02608405 0.02173671 0.01811393 0.01509494] in EMRI branch
# FullYearCombinedLiteGlobalFit (full_year_combined_lite) — Laptop-smoke twin of full_year_combined: one month instead of a year, 10 iterations, 4 walkers x 2 temps, CPU.
#   built: True
#   headline:
#     nwalkers = 4
#     ntemps = 2
#     dt = 2.5
#     num_iterations = 2
#     file_store_dir = './gf_output_gallery/'
#     base_file_name = 'gallery_full_year_combined_lite'
#     gpus = None
#     gpu_backend = 'auto'
#     tobs_target = 2592000.0
#     min_freq = 0.0001
#     max_freq = 0.025
#     tdi_chan = 'XYZ'
#     window_tukey_alpha = 0.0
#     mojito_data_path = '/Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/'
#     use_gpu = False
#   branches: ['emri']
#     emri: SourceEMRISettings  [built: EMRISetup]
#   recipe:
#     [pe] full_pe:
#         emri_pe  <- stock branch=emri
#   setup_function: setup_recipe
# 274427

# %% [markdown]
# **Multi-leaf specifics:** each source branch is a reversible-jump
# forest — `nleaves_max > 1` — because the number of MBHs / EMRIs / SOBBHs
# is unknown and sampled. The engine registers a `signal_gen` on each branch
# so it builds and *subtracts* every leaf's template from the shared
# residual under the hood (the `signal_gen` path from
# [`01` §Per-branch source info](01_GlobalFitQuickstart.ipynb)); the moves
# then resample each leaf. `all_sources` reuses this exact source setup —
# `full_year_combined` is just those three branches on their own over a full
# year.
#
# **Production launch:** `erebor.full_year_combined()` (mojito L1, a full
# year; `TOBS_TARGET`, `CHOP_WINDOW=1` for a merger-centered MBH snippet).

# %% [markdown]
# ## `all_sources` -- the six-branch flagship
#
# **TL;DR.** The real joint global fit: **all six branches** -- `gb`, `psd`,
# `galfor`, `mbh`, `emri`, `sobbh` -- composed from the exact per-branch
# setups of the variants above (the `gb_no_fg` GB down to 0.1 mHz, the noise
# `psd`/`galfor`, the `full_year` MBH/EMRI/SOBBH). This is the long pole; we
# **inspect its configuration** here without building it, and leave the
# build+run to notebook 01. Data:
# `mojito` (default) / `synthetic` / `sangria`.

# %%
fit = erebor.all_sources_lite(file_store_dir=GALLERY_DIR, base_file_name="gallery_all_sources_lite")
fit.general.data_mode = "synthetic"     # all six streams in-process, no external data
fit.general.synthetic_injections = "prior"   # prior draws; zero mojito needed
fit.general.num_iterations = 2
print(fit.describe())
# Out:
# AllSourcesLiteGlobalFit (all_sources_lite) — Laptop-smoke twin of all_sources: the same six branches and machinery on a small WDM grid (nf=720, nt=180), 10 iterations, 4 walkers x 2 temps, narrow GB band, CPU. Scale any knob back up to reach the full model (and vice-versa via all_sources(lite=True)).
#   built: False
#   headline:
#     nwalkers = 4
#     ntemps = 2
#     dt = 5.0
#     num_iterations = 2
#     file_store_dir = './gf_output_gallery/'
#     base_file_name = 'gallery_all_sources_lite'
#     gpus = None
#     gpu_backend = 'auto'
#     tobs_target = 7776000.0
#     min_freq = 0.0001
#     max_freq = 0.025
#     tdi_chan = 'XYZ'
#     window_tukey_alpha = 0.0
#     mojito_data_path = '/Users/mkatz/.mojito_cache/brickmarket/mojito_light_v1_0_0/'
#     use_gpu = False
#   branches: ['gb', 'psd', 'galfor', 'mbh', 'emri', 'sobbh']
#     gb: AllSourcesGBSettings
#     psd: NoisePSDSettings
#     galfor: GalForSettings
#     mbh: SourceMBHSettings
#     emri: SourceEMRISettings
#     sobbh: SourceSOBBHSettings
#   recipe:
#     [pe] full_pe:
#         psd_pe  <- stock branch=psd
#         mbh_pe  <- stock branch=mbh
#         emri_pe  <- stock branch=emri
#         sobbh_pe  <- stock branch=sobbh
#         rj_prior  <- stock branch=gb
#   setup_function: setup_recipe

# %% [markdown]
# **How it composes the others:** `all_sources` is not a new pipeline —
# it is the *union* of the branch setups you just saw. Its `gb` branch is
# the `gb_no_fg` setup (widened to the full band), its `psd`/`galfor` are the
# `noise` setup, and its `mbh`/`emri`/`sobbh` are the `full_year` setup —
# all six sampled together against one shared residual by one combined PE
# stage (`fit.list_moves()`). That composition is the whole design: each
# specialized variant is a slice of `all_sources`, so validating a branch in
# isolation validates it in the joint fit.
#
# **Production launch:** `erebor.all_sources()` (mojito L1 default; ~90-day
# WDM grid, `num_iterations` from `NUM_ITERATIONS`, GPU via `USE_GPU=1` /
# `GPUS`). See `LISAanalysistools/docs/global-fit-launch.md`.

# %%
print(fit.list_moves())

# NOT built here. all_sources_lite is the six-branch flagship: .build() resolves
# every branch and builds all six synthetic streams (~2.8 GB) on top of the four
# fits already built in this kernel -- enough to OOM an 8 GB laptop. describe()
# and list_moves() read the CONFIGURATION, which is what this gallery is about,
# and cost nothing: construction is validation + defaults only, with the heavy
# work deferred to .build(). Notebook 01 runs a stock fit end to end.
plt.close("all")
fit = None
gc.collect()
# Out:
# [pe] full_pe:
#     psd_pe  <- stock branch=psd
#     mbh_pe  <- stock branch=mbh
#     emri_pe  <- stock branch=emri
#     sobbh_pe  <- stock branch=sobbh
#     rj_prior  <- stock branch=gb
# 0

# %% [markdown]
# ## Recap
#
# | variant | branches | data modes | notes |
# |---|---|---|---|
# | `gb_no_fg` | `gb` | mojito / synthetic | fixed PSD, f > 6 mHz, RJ |
# | `noise_only` | `psd`, `galfor` | synthetic | noise is the signal |
# | `noise_sgwb` | `psd`, `galfor`, `sgwb` | synthetic | + power-law SGWB |
# | `full_year_combined` | `mbh`, `emri`, `sobbh` | mojito / synthetic | multi-leaf sources |
# | `all_sources` | all six | mojito / synthetic / sangria | the joint fit |
#
# Every full model has a `*_lite` twin (used throughout here) and scales to
# production by turning the knobs back up — see
# [`01` §Lite ↔ heavy](01_GlobalFitQuickstart.ipynb) and
# [`02`](02_StockGlobalFitsInDepth.ipynb) for the machinery. Launch details:
# `LISAanalysistools/docs/global-fit-launch.md`.
